# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('c1.csv')
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
regressor2 = PolynomialFeatures(degree = 3)
x_poly = regressor2.fit_transform(x)
regressor3 = linear_model.Ridge(alpha=0.0001)
regressor3.fit(x_poly,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=5.45717e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Ridge(alpha=0.0001)

# %%
plt.scatter(x,y,color = 'red')
plt.plot(x,regressor3.predict(x_poly),color= 'blue')
plt.title('Poly')
plt.xlabel('X')
plt.ylabel('t|y')
plt.show()
